# %% [markdown]
# ---
# title: "Non-medical Drug Use in Canada 🍁"
# author: "Jaekang Lee"
# date: "2021-05-02"
# categories: [python, glmer, data_exploration, data wrangling, report, PCA, mutual_info, drug]
# ---

# %% [markdown]
# # Non-medical Drug Use in Canada 🍁
# > DataFest 2021 @ University of Toronto

# %% [markdown]
# Full project - [link](https://github.com/leejaeka/Datafest2021)

# %% [markdown]
# ## Introduction & Background
# The growing non-medical use of prescription drugs is a
# global health concern. The Canadian’s Non-Medical Use of Prescription Drugs Survey data
# collected by RADARS® System gives an opportunity to understand the situation. Our team
# explored the raw survey data by visualizing, and came up with three research questions for
# the report.

# %% [markdown]
# ### Dataset
# https://github.com/leejaeka/Datafest2021/blob/main/data/CA-Data/Data%20Dictionary%20CA%2017Q3.doc

# %% [markdown]
# ### Data Wrangling/ Feature Engineering
# #### Assumptions
# 1. We assumed all surveys were answered truthfully and recorded without errors

# %% [markdown]
# #### Questions/Problems
# 1. There are 185 variables in total to consider. How do we explore all of these?
# 2. About 20% of the cells in the dataset are NANs.

# %% [markdown]
# #### Solution
# - We used principal components and mutual information to compute which variables to keep.
# - We fill the missing value with best logical answers. For example, variables on pregnancy for all males were ‘NA’. We fill the missing value with 0.

# %% [markdown]
# ### Research Question 1: What types of social groups best explain non-medical use?
# We used principal components and mutual information to compute which variables to keep.
# #### Steps
# 1. Principal components algorithm to reduce dimensionality and capture social groups.
# 2. Took the top components from PCA then calculated mutual information to find which component best explained ‘NMU’ variable
# 3. Visualized each social groups

# %%
#hide_input
from fastbook import *
from fastai.vision.widgets import *
one = PILImage.create("images/datafest/PCA_MI.png")

display(one)
#display(one.to_thumb(800,700))
# Out:
# C:\Users\tonyl\anaconda3\lib\site-packages\fastbook\__init__.py:18: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")
# PILImage mode=RGB size=1245x778

# %% [markdown]
# Above graph shows the process of capturing 'Top Non-Medical Drug Use Social Groups'.
# - **Top Mutual Information of 'NMU'**: MI scores of original dataset with 'NMU' as response variable. Showed that Opioid, Codeine and Coccaine were the top explanation for NMU.
# - **Principal Component Variance Capture Plots**: We can see that PCA succesfully captured about 90% of total variance with just 100 components.
# - **Top Mutual Information of 'NMU' with Principal Components**: Greatest score was 'PC3' followed by 'PC10' then so on. Below it, we can see the example of dissecting PC3 where it is used to find out that PC3 corresponds to people from Quebec.

# %% [markdown]
# View interactive visualization_1 in Tableau - [link](https://public.tableau.com/profile/jaekang#!/vizhome/PCA_MI/Dashboard1)

# %% [markdown]
# ### Top Non-Medical Drug Use Social Groups

# %%
#hide_input
two = PILImage.create("images/datafest/MAPS.png")
display(two)
# Out:
# PILImage mode=RGB size=1241x769

# %% [markdown]
# View interactive visualization_2 in Tableau - [link](https://public.tableau.com/profile/jaekang#!/vizhome/Canada_NMU2/Dashboard1)

# %%
#hide_input
three = PILImage.create("images/datafest/GROUPS.png")
display(three)
# Out:
# PILImage mode=RGB size=1237x773

# %% [markdown]
# The specificness of PCA's component interpretation allows us to analyze the group closely. (Without having to explore billions of possible combinations of groups)

# %%
#hide_input
four = PILImage.create("images/datafest/specific.png")
display(four)
# Out:
# PILImage mode=RGB size=1087x396

# %% [markdown]
# View interactive visualization_3 in Tableau - [link](https://public.tableau.com/profile/jaekang#!/vizhome/Canada_NMU2/Dashboard2)

# %%
#hide_input
five = PILImage.create("images/datafest/slide.png")
display(five)
# Out:
# PILImage mode=RGB size=783x588

# %% [markdown]
# ### Conclusion
# - Quebec was most severe social group suffering from Non-Medical Drug Use in Canada and we have looked at several other social groups

# %%
#hide_input
six = PILImage.create("images/datafest/conclusion.png")
display(six)
# Out:
# PILImage mode=RGB size=686x512
